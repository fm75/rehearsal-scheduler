# %% [markdown]
# # Explore example conflicts

# %%
import pandas as pd

# %%
conflicts_path = "data/conflicts.csv"

# %%
df = pd.read_csv(conflicts_path).dropna()
df = df.sort_values(by='conflicts', ascending=True)

# %%
pd.set_option('display.max_colwidth', None)
df.style.set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_590a9_row0_col0, #T_590a9_row0_col1, #T_590a9_row1_col0, #T_590a9_row1_col1, #T_590a9_row2_col0, #T_590a9_row2_col1, #T_590a9_row3_col0, #T_590a9_row3_col1, #T_590a9_row4_col0, #T_590a9_row4_col1, #T_590a9_row5_col0, #T_590a9_row5_col1, #T_590a9_row6_col0, #T_590a9_row6_col1, #T_590a9_row7_col0, #T_590a9_row7_col1, #T_590a9_row8_col0, #T_590a9_row8_col1, #T_590a9_row9_col0, #T_590a9_row9_col1, #T_590a9_row10_col0, #T_590a9_row10_col1, #T_590a9_row11_col0, #T_590a9_row11_col1, #T_590a9_row12_col0, #T_590a9_row12_col1, #T_590a9_row13_col0, #T_590a9_row13_col1, #T_590a9_row14_col0, #T_590a9_row14_col1, #T_590a9_row15_col0, #T_590a9_row15_col1, #T_590a9_row16_col0, #T_590a9_row16_col1, #T_590a9_row17_col0, #T_590a9_row17_col1, #T_590a9_row18_col0, #T_590a9_row18_col1, #T_590a9_row19_col0, #T_590a9_row19_col1, #T_590a9_row20_col0, #T_590a9_row20_col1, #T_590a9_row21_col0, #T_590a9_row21_col1, #T_590a9_row22_col0, #T_590a9_row22_col1, #T_590a9_row23_col0, #T_590a9_row23_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_590a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_590a9_level0_col0" class="col_heading level0 col0" >dancer_id</th>
#       <th id="T_590a9_level0_col1" class="col_heading level0 col1" >conflicts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_590a9_level0_row0" class="row_heading level0 row0" >33</th>
#       <td id="T_590a9_row0_col0" class="data row0 col0" >d_034</td>
#       <td id="T_590a9_row0_col1" class="data row0 col1" > 0ut Dec. 17, 23, 24</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row1" class="row_heading level0 row1" >8</th>
#       <td id="T_590a9_row1_col0" class="data row1 col0" >d_009</td>
#       <td id="T_590a9_row1_col1" class="data row1 col1" > Dec 30 good, Dec 31 no good</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row2" class="row_heading level0 row2" >27</th>
#       <td id="T_590a9_row2_col0" class="data row2 col0" >d_028</td>
#       <td id="T_590a9_row2_col1" class="data row2 col1" > Holidays are all good Tues 12/23 not before 1:30</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row3" class="row_heading level0 row3" >24</th>
#       <td id="T_590a9_row3_col0" class="data row3 col0" >d_025</td>
#       <td id="T_590a9_row3_col1" class="data row3 col1" > T after 12:15</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row4" class="row_heading level0 row4" >28</th>
#       <td id="T_590a9_row4_col0" class="data row4 col0" >d_029</td>
#       <td id="T_590a9_row4_col1" class="data row4 col1" >12/21- Available
# 12/23 & 12/24- Not available (Michigan)
# 12/28, 12/30 & 12/31- Available</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row5" class="row_heading level0 row5" >21</th>
#       <td id="T_590a9_row5_col0" class="data row5 col0" >d_022</td>
#       <td id="T_590a9_row5_col1" class="data row5 col1" >4th Tuesday of the month available after noon</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_590a9_row6_col0" class="data row6 col0" >d_003</td>
#       <td id="T_590a9_row6_col1" class="data row6 col1" >All dates good but out Tues 12/23</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row7" class="row_heading level0 row7" >4</th>
#       <td id="T_590a9_row7_col0" class="data row7 col0" >d_005</td>
#       <td id="T_590a9_row7_col1" class="data row7 col1" >Christmas cruise 12/20-12/27</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row8" class="row_heading level0 row8" >5</th>
#       <td id="T_590a9_row8_col0" class="data row8 col0" >d_006</td>
#       <td id="T_590a9_row8_col1" class="data row8 col1" >Christmas cruise 12/20-12/27 Also, I work on Sunday, Monday and Tuesday until 2:30 PM.</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_590a9_row9_col0" class="data row9 col0" >d_002</td>
#       <td id="T_590a9_row9_col1" class="data row9 col1" >Christmas np</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row10" class="row_heading level0 row10" >22</th>
#       <td id="T_590a9_row10_col0" class="data row10 col0" >d_023</td>
#       <td id="T_590a9_row10_col1" class="data row10 col1" >Dances all together is ideal, holidays are all good</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row11" class="row_heading level0 row11" >34</th>
#       <td id="T_590a9_row11_col0" class="data row11 col0" >d_035</td>
#       <td id="T_590a9_row11_col1" class="data row11 col1" >Dates we gave for holidays are good.  </td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row12" class="row_heading level0 row12" >36</th>
#       <td id="T_590a9_row12_col0" class="data row12 col0" >d_037</td>
#       <td id="T_590a9_row12_col1" class="data row12 col1" >None at this time</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row13" class="row_heading level0 row13" >0</th>
#       <td id="T_590a9_row13_col0" class="data row13 col0" >d_001</td>
#       <td id="T_590a9_row13_col1" class="data row13 col1" >Out December 17, 20-27, Sun Dec 28 is good, no Dec 30 or 31 (working)</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row14" class="row_heading level0 row14" >13</th>
#       <td id="T_590a9_row14_col0" class="data row14 col0" >d_014</td>
#       <td id="T_590a9_row14_col1" class="data row14 col1" >Out Sun 12/21 -Fri 12/26</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row15" class="row_heading level0 row15" >9</th>
#       <td id="T_590a9_row15_col0" class="data row15 col0" >d_010</td>
#       <td id="T_590a9_row15_col1" class="data row15 col1" >Please no Sundays, No Tues 12/30</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row16" class="row_heading level0 row16" >6</th>
#       <td id="T_590a9_row16_col0" class="data row16 col0" >d_007</td>
#       <td id="T_590a9_row16_col1" class="data row16 col1" >T after 12:15, </td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row17" class="row_heading level0 row17" >7</th>
#       <td id="T_590a9_row17_col0" class="data row17 col0" >d_008</td>
#       <td id="T_590a9_row17_col1" class="data row17 col1" >T after 12:15, Sundays after after 2:30, </td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row18" class="row_heading level0 row18" >14</th>
#       <td id="T_590a9_row18_col0" class="data row18 col0" >d_015</td>
#       <td id="T_590a9_row18_col1" class="data row18 col1" >T after 12:15,Wednesdays after 2:15.   All dates good but out Tues 12/23, </td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row19" class="row_heading level0 row19" >17</th>
#       <td id="T_590a9_row19_col0" class="data row19 col0" >d_018</td>
#       <td id="T_590a9_row19_col1" class="data row19 col1" >Tues 12/23 before 2</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row20" class="row_heading level0 row20" >35</th>
#       <td id="T_590a9_row20_col0" class="data row20 col0" >d_036</td>
#       <td id="T_590a9_row20_col1" class="data row20 col1" >Tuesdays - I am good from 1:00-4:00pm.   I could get to CC by 12:30 by pushing it a bit,
# Wednesdays - I would appreciate if I could be scheduled for anything AFTER MaryAnn's Tap & Jazz. </td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row21" class="row_heading level0 row21" >12</th>
#       <td id="T_590a9_row21_col0" class="data row21 col0" >d_013</td>
#       <td id="T_590a9_row21_col1" class="data row21 col1" >Wed after 2:00, Out  12/31</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row22" class="row_heading level0 row22" >32</th>
#       <td id="T_590a9_row22_col0" class="data row22 col0" >d_033</td>
#       <td id="T_590a9_row22_col1" class="data row22 col1" >Wed not after 4 pm</td>
#     </tr>
#     <tr>
#       <th id="T_590a9_level0_row23" class="row_heading level0 row23" >10</th>
#       <td id="T_590a9_row23_col0" class="data row23 col0" >d_011</td>
#       <td id="T_590a9_row23_col1" class="data row23 col1" >if possible if scheduling me on Sundays please have  schedule after 1:00, </td>
#     </tr>
#   </tbody>
# </table>

# %%
len(df)
# Out:
# 24
